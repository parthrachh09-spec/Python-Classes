# %%
name=input ("Whats your name")
hobbie=input ("Whats your hobbie")
vegetable=input ("Whats your Favourtie vegtable")
# Out:
# Whats your name Parth
# Whats your hobbie Playing Fottball
# Whats your Favourtie vegtable Olives,Jalepenos

# %%
print("Youre information is",name,hobbie,vegetable)
# Out:
# Youre information is Parth Playing Fottball Olives,Jalepenos

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Indu Bhatia\Documents\Python Classes i\Python Classes
