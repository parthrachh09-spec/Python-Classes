# %%
def sum(a,b):
    print("The sum is: ", a+b)

def subtract (a,b):
    print("The diffrence is: ", a-b)
    
def multiply (a,b):
    print("The product is: ", a*b)

def divide (a,b):
    print("The diffrence is: ", a/b)

n1=int(input("ENter number 1:  "))
n2=int(input("ENter number 2: "))

sum(n1,n2)
subtract(n1,n2)
multiply(n1,n2)
divide(n1,n2)
# Out:
# ENter number 1:   2
# ENter number 2:  455556
# The sum is:  455558
# The diffrence is:  -455554
# The product is:  911112
# The diffrence is:  4.39023961927842e-06
