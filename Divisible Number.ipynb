# %%
numerator= int(input("Enter the numerator : "))
denominater=int(input("Enter the denominator : "))
if numerator%denominator==0:
    print("The numbers are divisble")
else:
    print("The numbers are nondivisble")
# Out:
# Enter the numerator :  6
# Enter the denominator :  4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 numerator= int(input("Enter the numerator : "))
#       2 denometer=int(input("Enter the denominator : "))
# ----> 3 if numerator%denominator==0:
#       4     print("The numbers are divisble")
#       5 else:
#
# NameError: name 'denominator' is not defined
