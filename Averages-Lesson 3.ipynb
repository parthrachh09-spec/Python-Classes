# %%
PE=int(input("Enter PE marks"))
Biology=int(input("Enter Biology marks"))
Chemistry=int(input("Enter Chemistry marks"))
Music=int(input("Enter Music marks"))
# Out:
# Enter PE marks 100
# Enter Biology marks 234
# Enter Chemistry marks 10000000
# Enter Music marks 97

# %%
avg=(PE+Biology+Chemistry+Music)/4
print(avg)
# Out:
# 2500107.75
