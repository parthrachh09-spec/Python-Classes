# %%
name1="Parth"
name2="Mark"
print(name1 is not name2)
# Out:
# True

# %%
name1="Parth"
name2="Parth"
print(name1 is name2)
# Out:
# True

# %%
name="Jhon"
if type(name) is str:
   print("Stringe datatype")
else:
      print("Datatype is diffrent")
# Out:
# Stringe datatype

# %%
import sys

print(sys.executable)
# Out:
# C:\Users\Indu Bhatia\anaconda3\python.exe
