# %%
name="Parth"
print(type(name))
# Out:
# <class 'str'>

# %%
age=18
print(type(age))
# Out:
# <class 'int'>

# %%
marks=90.6
print(type(marks))
# Out:
# <class 'float'>

# %%
score=45.7
print(type(score))
# Out:
# <class 'float'>

# %%
value=True
print(type(value))
# Out:
# <class 'bool'>
