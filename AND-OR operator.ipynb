# %%
username=input("Enter username")
password=input("Enter password:") 

if username=="admin123" and password=="password":
    print("Logim sucessful")
else:
    print("Either username or password is incorrect")
