# %%
import turtle
t=turtle.Turtle()

t.color("pink")
turtle.bgcolor("yellow")
t.pensize(!0)

for i in range(4):
    t.forward(200)
    t.right(90)

turtle.done()
# Out:
#   Cell In[1], line 6
#     t.pensize(!0)
#               ^
# SyntaxError: invalid syntax
