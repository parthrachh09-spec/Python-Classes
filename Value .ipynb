# %%
n=1
sum=0

while n<=5:
    num= int(input("Enter a number"))
    sum=sum+num
    n=n+1

print(sum)
# Out:
# Enter a number 2
# Enter a number 3
# Enter a number 1
# Enter a number 2
# Enter a number 3
# 11
