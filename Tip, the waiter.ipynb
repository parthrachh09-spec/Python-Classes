# %%
def calculate_tip(total, percent):
    tip=(percent/100)*total
    print("The tip you should give is: ", tip)

bill=int(input("What's the total bill: "))
t=int(input("Whats the tip percentage: "))


calculate_tip(bill,
